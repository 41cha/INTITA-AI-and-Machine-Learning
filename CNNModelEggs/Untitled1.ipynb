# %%
pip install DirectoryControl==0.1.0.3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from directorycontrol import fortest

fortest('fdf')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from directorycontrol import fortest
#       3 fortest('fdf')
#
# ModuleNotFoundError: No module named 'directorycontrol'
