# %%
pip install DirectoryControl==0.1.0.2
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for DirectoryControl: filename=directorycontrol-0.1.0.2-py3-none-any.whl size=1250 sha256=cbfe81102f51ab65560df7b8bce918abcc337eacdaf4bf2f1ee46d326ac48d2a
#   Stored in directory: c:\users\intit\appdata\local\pip\cache\wheels\f3\3b\f0\0e28a641d05a81f8fd0130f1105b7954de67f744c435baf6fb
# Successfully built DirectoryControl
# ...
#   Attempting uninstall: DirectoryControl
#     Found existing installation: DirectoryControl 0.1.0.1
#     Uninstalling DirectoryControl-0.1.0.1:
#       Successfully uninstalled DirectoryControl-0.1.0.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from DirectoryControl import ls, pwd, mkdir, rm, cat, cp, mv, fortest
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from DirectoryControl import ls, pwd, mkdir, rm, cat, cp, mv, fortest
#
# ModuleNotFoundError: No module named 'DirectoryControl'

# %%
import importlib.metadata as m

print(m.distribution("DirectoryControl").files)
# Out:
# [PackagePath('directorycontrol-0.1.0.2.dist-info/INSTALLER'), PackagePath('directorycontrol-0.1.0.2.dist-info/METADATA'), PackagePath('directorycontrol-0.1.0.2.dist-info/RECORD'), PackagePath('directorycontrol-0.1.0.2.dist-info/REQUESTED'), PackagePath('directorycontrol-0.1.0.2.dist-info/WHEEL'), PackagePath('directorycontrol-0.1.0.2.dist-info/top_level.txt')]

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# C:\Users\intit\AppData\Local\Programs\Python\Python313\python.exe
# 3.13.7 (tags/v3.13.7:bcee1c3, Aug 14 2025, 14:15:11) [MSC v.1944 64 bit (AMD64)]

# %%
# !python -c "import sys; print(sys.executable); print(sys.version)"
# Out:
# C:\Users\intit\AppData\Local\Programs\Python\Python313\python.exe
# 3.13.7 (tags/v3.13.7:bcee1c3, Aug 14 2025, 14:15:11) [MSC v.1944 64 bit (AMD64)]

# %%
import importlib.metadata as m
dist = m.distribution("DirectoryControl")
print(dist.files)
# Out:
# [PackagePath('directorycontrol-0.1.0.2.dist-info/INSTALLER'), PackagePath('directorycontrol-0.1.0.2.dist-info/METADATA'), PackagePath('directorycontrol-0.1.0.2.dist-info/RECORD'), PackagePath('directorycontrol-0.1.0.2.dist-info/REQUESTED'), PackagePath('directorycontrol-0.1.0.2.dist-info/WHEEL'), PackagePath('directorycontrol-0.1.0.2.dist-info/top_level.txt')]

# %%
import sys
print(sys.executable)  # має показати твій шлях
!"{sys.executable}" -m pip install --force-reinstall DirectoryControl==0.1.0.2
# Out:
# C:\Users\intit\AppData\Local\Programs\Python\Python313\python.exe
# ...
#   Using cached directorycontrol-0.1.0.2-py3-none-any.whl
# ...
#   Attempting uninstall: DirectoryControl
#     Found existing installation: DirectoryControl 0.1.0.2
#     Uninstalling DirectoryControl-0.1.0.2:
#       Successfully uninstalled DirectoryControl-0.1.0.2
# ...

# %%
import importlib.metadata as m
print(m.version("DirectoryControl"))
print(m.distribution("DirectoryControl").files)
# Out:
# 0.1.0.2
# [PackagePath('directorycontrol-0.1.0.2.dist-info/INSTALLER'), PackagePath('directorycontrol-0.1.0.2.dist-info/METADATA'), PackagePath('directorycontrol-0.1.0.2.dist-info/RECORD'), PackagePath('directorycontrol-0.1.0.2.dist-info/REQUESTED'), PackagePath('directorycontrol-0.1.0.2.dist-info/WHEEL'), PackagePath('directorycontrol-0.1.0.2.dist-info/top_level.txt')]
